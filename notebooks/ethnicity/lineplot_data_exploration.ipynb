# %%
# Import necessary libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
#download CSV file and sort values by ascending population

americanindian_mortality = pd.read_csv('resources/americanindian_mortality.csv')
americanindian_mortality.sort_values('Percent of Population', 
                           ascending=True,
                           inplace=True)
americanindian_mortality
# Out:
#         County  Percent of Death  Percent of Population
# 1       Orange            0.0016                 0.0020
# 0  Los Angeles            0.0022                 0.0070
# 2    San Diego            0.0030                 0.0071

# %%
#Set the plot with % of Population and % of Death in the xAxis and yAxis respectively.

americanindian_fig = plt.plot(americanindian_mortality['Percent of Population'], 
        americanindian_mortality['Percent of Death'],
        color='green', 
         marker='o', 
         linestyle='solid', 
         linewidth=2, 
         markersize=5)
plt.title('American Indian Mortality Rate vs. Population Density')
plt.xlabel('Percent of Population')
plt.ylabel('Percent of Death')

americanindian_fig

#save the figure into the figures folder
plt.savefig('figures/americanindianfig.png')

# %%
#download CSV file and sort values by ascending population

asian_mortality = pd.read_csv('resources/asian_mortality.csv')
asian_mortality.sort_values('Percent of Population', 
                           ascending=True,
                           inplace=True)
asian_mortality
# Out:
#         County  Percent of Death  Percent of Population
# 2    San Diego              0.11                   0.12
# 0  Los Angeles              0.14                   0.15
# 1       Orange              0.21                   0.21

# %%
#Set the plot with % of Population and % of Death in the xAxis and yAxis respectively.

asian_fig = plt.plot(asian_mortality['Percent of Population'], 
        asian_mortality['Percent of Death'],
        color='red', 
         marker='o', 
         linestyle='solid', 
         linewidth=2, 
         markersize=5)
plt.title('Asian Mortality Rate vs. Population Density')
plt.xlabel('Percent of Population')
plt.ylabel('Percent of Death')

asian_fig

#save the figure into the figures folder
plt.savefig('figures/asianfig.png')

# %%
#download CSV file and sort values by ascending population

black_mortality = pd.read_csv('resources/black_mortality.csv')
black_mortality.sort_values('Percent of Population', 
                           ascending=True,
                           inplace=True)
black_mortality
# Out:
#         County  Percent of Death  Percent of Population
# 1       Orange              0.01                   0.02
# 2    San Diego              0.04                   0.05
# 0  Los Angeles              0.08                   0.08

# %%
#Set the plot with % of Population and % of Death in the xAxis and yAxis respectively.

black_fig = plt.plot(black_mortality['Percent of Population'], 
        black_mortality['Percent of Death'],
        color='Blue', 
        marker='o', 
        linestyle='solid', 
        linewidth=2, 
        markersize=5)
plt.title('Black Mortality Rate vs. Population Density')
plt.xlabel('Percent of Population')
plt.ylabel('Percent of Death')

black_fig

#save the figure into the figures folder
plt.savefig('figures/blackfig.png')

# %%
hispanic_latino_mortality = pd.read_csv('resources/hispanic_latino_mortality.csv')
hispanic_latino_mortality.sort_values('Percent of Population', 
                           ascending=True,
                           inplace=True)
hispanic_latino_mortality
# Out:
#         County  Percent of Death  Percent of Population
# 2    San Diego              0.45                   0.34
# 1       Orange              0.38                   0.35
# 0  Los Angeles              0.54                   0.49

# %%
#Set the plot with % of Population and % of Death in the xAxis and yAxis respectively.

hispanic_latino_fig = plt.plot(hispanic_latino_mortality['Percent of Population'], 
        hispanic_latino_mortality['Percent of Death'],
        color='purple', 
        marker='o', 
        linestyle='solid', 
        linewidth=2, 
        markersize=5)
plt.title('Hispanic or Latino Mortality Rate vs. Population Density')
plt.xlabel('Percent of Population')
plt.ylabel('Percent of Death')

hispanic_latino_fig

#save the figure into the figures folder
plt.savefig('figures/hispaniclatinofig.png')

# %%
#download CSV file and sort values by ascending population

white_mortality = pd.read_csv('resources/white_mortality.csv')
white_mortality.sort_values('Percent of Population', 
                           ascending=True,
                           inplace=True)
white_mortality
# Out:
#         County  Percent of Death  Percent of Population
# 0       Orange              0.37                   0.39
# 1  Los Angeles              0.23                   0.51
# 2    San Diego              0.36                   0.75

# %%
#Set the plot with % of Population and % of Death in the xAxis and yAxis respectively.

white_fig = plt.plot(white_mortality['Percent of Population'], 
        white_mortality['Percent of Death'],
        color='gray', 
        marker='o', 
        linestyle='solid', 
        linewidth=2, 
        markersize=5)
plt.title('White Mortality Rate vs. Population Density')
plt.xlabel('Percent of Population')
plt.ylabel('Percent of Death')

white_fig

#save the figure into the figures folder
plt.savefig('figures/whitefig.png')

# %%
#Merge all plots into one to view all data as a whole and make inferences about trends through each Ethnic Group

merged_fig = plt.plot(white_mortality['Percent of Population'], 
            white_mortality['Percent of Death'],
            color='gray', 
            marker='o', 
            linestyle='solid', 
            linewidth=2, 
            markersize=5)
plt.plot(hispanic_latino_mortality['Percent of Population'], 
            hispanic_latino_mortality['Percent of Death'],
            color='purple', 
            marker='o', 
            linestyle='solid', 
            linewidth=2, 
            markersize=5)
plt.plot(black_mortality['Percent of Population'], 
            black_mortality['Percent of Death'],
            color='Blue', 
            marker='o', 
            linestyle='solid', 
            linewidth=2, 
            markersize=5)
plt.plot(asian_mortality['Percent of Population'], 
            asian_mortality['Percent of Death'],
            color='red', 
            marker='o', 
            linestyle='solid', 
            linewidth=2, 
            markersize=5)
plt.plot(americanindian_mortality['Percent of Population'], 
americanindian_mortality['Percent of Death'],
color='green', 
marker='o', 
linestyle='solid', 
linewidth=2, 
markersize=5)
plt.title('Mortality Rate vs. Population Density')
plt.xlabel('Percent of Population')
plt.ylabel('Percent of Death')
plt.legend('WHBAN')

#save the figure into the figures folder
plt.savefig('figures/mergedfig.png')
